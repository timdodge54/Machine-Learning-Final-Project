# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# %%
# Load the data
data = pd.read_csv('../data/train_1/train_1.csv')
display(data)
# Out:
#                                                      Page  2015-07-01  \
# 0                 2NE1_zh.wikipedia.org_all-access_spider        18.0
# 1                  2PM_zh.wikipedia.org_all-access_spider        11.0
# 2                   3C_zh.wikipedia.org_all-access_spider         1.0
# 3              4minute_zh.wikipedia.org_all-access_spider        35.0
# 4       52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN
# ...                                                   ...         ...
# 145058  Underworld_(serie_de_películas)_es.wikipedia.o...         NaN
# 145059  Resident_Evil:_Capítulo_Final_es.wikipedia.org...         NaN
# 145060  Enamorándome_de_Ramón_es.wikipedia.org_all-acc...         NaN
# 145061  Hasta_el_último_hombre_es.wikipedia.org_all-ac...         NaN
# 145062  Francisco_el_matemático_(serie_de_televisión_d...         NaN
#
#         2015-07-02  2015-07-03  2015-07-04  2015-07-05  2015-07-06  \
# 0             11.0         5.0        13.0        14.0         9.0
# 1             14.0        15.0        18.0        11.0        13.0
# 2              0.0         1.0         1.0         0.0         4.0
# 3             13.0        10.0        94.0         4.0        26.0
# 4              NaN         NaN         NaN         NaN         NaN
# ...            ...         ...         ...         ...         ...
# 145058         NaN         NaN         NaN         NaN         NaN
# 145059         NaN         NaN         NaN         NaN         NaN
# 145060         NaN         NaN         NaN         NaN         NaN
# 145061         NaN         NaN         NaN         NaN         NaN
# 145062         NaN         NaN         NaN         NaN         NaN
#
#         2015-07-07  2015-07-08  2015-07-09  ...  2016-12-22  2016-12-23  \
# 0              9.0        22.0        26.0  ...        32.0        63.0
# 1             22.0        11.0        10.0  ...        17.0        42.0
# 2              0.0         3.0         4.0  ...         3.0         1.0
# 3             14.0         9.0        11.0  ...        32.0        10.0
# 4              NaN         NaN         NaN  ...        48.0         9.0
# ...            ...         ...         ...  ...         ...         ...
# 145058         NaN         NaN         NaN  ...         NaN         NaN
# 145059         NaN         NaN         NaN  ...         NaN         NaN
# 145060         NaN         NaN         NaN  ...         NaN         NaN
# 145061         NaN         NaN         NaN  ...         NaN         NaN
# 145062         NaN         NaN         NaN  ...         NaN         NaN
#
#         2016-12-24  2016-12-25  2016-12-26  2016-12-27  2016-12-28  \
# 0             15.0        26.0        14.0        20.0        22.0
# 1             28.0        15.0         9.0        30.0        52.0
# 2              1.0         7.0         4.0         4.0         6.0
# 3             26.0        27.0        16.0        11.0        17.0
# 4             25.0        13.0         3.0        11.0        27.0
# ...            ...         ...         ...         ...         ...
# 145058         NaN         NaN        13.0        12.0        13.0
# 145059         NaN         NaN         NaN         NaN         NaN
# 145060         NaN         NaN         NaN         NaN         NaN
# 145061         NaN         NaN         NaN         NaN         NaN
# 145062         NaN         NaN         NaN         NaN         NaN
#
#         2016-12-29  2016-12-30  2016-12-31
# 0             19.0        18.0        20.0
# 1             45.0        26.0        20.0
# 2              3.0         4.0        17.0
# 3             19.0        10.0        11.0
# 4             13.0        36.0        10.0
# ...            ...         ...         ...
# 145058         3.0         5.0        10.0
# 145059         NaN         NaN         NaN
# 145060         NaN         NaN         NaN
# 145061         NaN         NaN         NaN
# 145062         NaN         NaN         NaN
#
# [145063 rows x 551 columns]

# %%
# print the dimensions of the dataset
print(data.shape)
# Out:
# (145063, 551)

# %%
# Create a mask for rows where splitting by '_' doesn't yield exactly four parts
mask = data['Page'].str.split('_').apply(lambda x: len(x) != 4)

# Filter and display those rows
problem_rows = data[mask]
display(problem_rows)
# Out:
#                                                      Page  2015-07-01  \
# 4       52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN
# 11      Ahq_e-Sports_Club_zh.wikipedia.org_all-access_...         2.0
# 12      All_your_base_are_belong_to_us_zh.wikipedia.or...         2.0
# 17            Apple_II_zh.wikipedia.org_all-access_spider         4.0
# 18              As_One_zh.wikipedia.org_all-access_spider        13.0
# ...                                                   ...         ...
# 145058  Underworld_(serie_de_películas)_es.wikipedia.o...         NaN
# 145059  Resident_Evil:_Capítulo_Final_es.wikipedia.org...         NaN
# 145060  Enamorándome_de_Ramón_es.wikipedia.org_all-acc...         NaN
# 145061  Hasta_el_último_hombre_es.wikipedia.org_all-ac...         NaN
# 145062  Francisco_el_matemático_(serie_de_televisión_d...         NaN
#
#         2015-07-02  2015-07-03  2015-07-04  2015-07-05  2015-07-06  \
# 4              NaN         NaN         NaN         NaN         NaN
# 11             1.0         4.0         4.0         2.0         6.0
# 12             5.0         5.0         1.0         3.0         3.0
# 17             8.0         4.0         9.0         7.0         4.0
# 18             7.0        14.0        11.0        20.0         5.0
# ...            ...         ...         ...         ...         ...
# 145058         NaN         NaN         NaN         NaN         NaN
# 145059         NaN         NaN         NaN         NaN         NaN
# 145060         NaN         NaN         NaN         NaN         NaN
# 145061         NaN         NaN         NaN         NaN         NaN
# 145062         NaN         NaN         NaN         NaN         NaN
#
#         2015-07-07  2015-07-08  2015-07-09  ...  2016-12-22  2016-12-23  \
# 4              NaN         NaN         NaN  ...        48.0         9.0
# 11             3.0         6.0         9.0  ...         8.0        17.0
# 12             5.0         3.0        17.0  ...         5.0         4.0
# 17            15.0         9.0        17.0  ...         5.0        14.0
# 18            32.0        11.0         6.0  ...        37.0        12.0
# ...            ...         ...         ...  ...         ...         ...
# 145058         NaN         NaN         NaN  ...         NaN         NaN
# 145059         NaN         NaN         NaN  ...         NaN         NaN
# 145060         NaN         NaN         NaN  ...         NaN         NaN
# 145061         NaN         NaN         NaN  ...         NaN         NaN
# 145062         NaN         NaN         NaN  ...         NaN         NaN
#
#         2016-12-24  2016-12-25  2016-12-26  2016-12-27  2016-12-28  \
# 4             25.0        13.0         3.0        11.0        27.0
# 11            18.0        48.0        19.0        14.0         9.0
# 12             4.0         5.0         2.0         9.0         7.0
# 17             8.0        11.0         8.0        24.0        10.0
# 18             7.0        11.0        13.0        17.0        13.0
# ...            ...         ...         ...         ...         ...
# 145058         NaN         NaN        13.0        12.0        13.0
# 145059         NaN         NaN         NaN         NaN         NaN
# 145060         NaN         NaN         NaN         NaN         NaN
# 145061         NaN         NaN         NaN         NaN         NaN
# 145062         NaN         NaN         NaN         NaN         NaN
#
#         2016-12-29  2016-12-30  2016-12-31
# 4             13.0        36.0        10.0
# 11            23.0        11.0         7.0
# 12             4.0         5.0         0.0
# 17            15.0        12.0        11.0
# 18            12.0         9.0         8.0
# ...            ...         ...         ...
# 145058         3.0         5.0        10.0
# 145059         NaN         NaN         NaN
# 145060         NaN         NaN         NaN
# 145061         NaN         NaN         NaN
# 145062         NaN         NaN         NaN
#
# [90097 rows x 551 columns]

# %%
import pandas as pd

# This regex:
#   (?P<Title>.+)     => Captures everything (including underscores) as the Title (greedy)
#   _(?P<Project>[^_]+)  => Captures the Project field (no underscores)
#   _(?P<Access>[^_]+)   => Captures the Access field
#   _(?P<Agent>[^_]+)$   => Captures the Agent field at the end
pattern = r'^(?P<Title>.+)_(?P<Project>[^_]+)_(?P<Access>[^_]+)_(?P<Agent>[^_]+)$'

data[['Title', 'Project', 'Access', 'Agent']] = data['Page'].str.extract(pattern)
display(data)
# Out:
#                                                      Page  2015-07-01  \
# 0                 2NE1_zh.wikipedia.org_all-access_spider        18.0
# 1                  2PM_zh.wikipedia.org_all-access_spider        11.0
# 2                   3C_zh.wikipedia.org_all-access_spider         1.0
# 3              4minute_zh.wikipedia.org_all-access_spider        35.0
# 4       52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN
# ...                                                   ...         ...
# 145058  Underworld_(serie_de_películas)_es.wikipedia.o...         NaN
# 145059  Resident_Evil:_Capítulo_Final_es.wikipedia.org...         NaN
# 145060  Enamorándome_de_Ramón_es.wikipedia.org_all-acc...         NaN
# 145061  Hasta_el_último_hombre_es.wikipedia.org_all-ac...         NaN
# 145062  Francisco_el_matemático_(serie_de_televisión_d...         NaN
#
#         2015-07-02  2015-07-03  2015-07-04  2015-07-05  2015-07-06  \
# 0             11.0         5.0        13.0        14.0         9.0
# 1             14.0        15.0        18.0        11.0        13.0
# 2              0.0         1.0         1.0         0.0         4.0
# 3             13.0        10.0        94.0         4.0        26.0
# 4              NaN         NaN         NaN         NaN         NaN
# ...            ...         ...         ...         ...         ...
# 145058         NaN         NaN         NaN         NaN         NaN
# 145059         NaN         NaN         NaN         NaN         NaN
# 145060         NaN         NaN         NaN         NaN         NaN
# 145061         NaN         NaN         NaN         NaN         NaN
# 145062         NaN         NaN         NaN         NaN         NaN
#
#         2015-07-07  2015-07-08  2015-07-09  ...  2016-12-26  2016-12-27  \
# 0              9.0        22.0        26.0  ...        14.0        20.0
# 1             22.0        11.0        10.0  ...         9.0        30.0
# 2              0.0         3.0         4.0  ...         4.0         4.0
# 3             14.0         9.0        11.0  ...        16.0        11.0
# 4              NaN         NaN         NaN  ...         3.0        11.0
# ...            ...         ...         ...  ...         ...         ...
# 145058         NaN         NaN         NaN  ...        13.0        12.0
# 145059         NaN         NaN         NaN  ...         NaN         NaN
# 145060         NaN         NaN         NaN  ...         NaN         NaN
# 145061         NaN         NaN         NaN  ...         NaN         NaN
# 145062         NaN         NaN         NaN  ...         NaN         NaN
#
#         2016-12-28  2016-12-29  2016-12-30  2016-12-31  \
# 0             22.0        19.0        18.0        20.0
# 1             52.0        45.0        26.0        20.0
# 2              6.0         3.0         4.0        17.0
# 3             17.0        19.0        10.0        11.0
# 4             27.0        13.0        36.0        10.0
# ...            ...         ...         ...         ...
# 145058        13.0         3.0         5.0        10.0
# 145059         NaN         NaN         NaN         NaN
# 145060         NaN         NaN         NaN         NaN
# 145061         NaN         NaN         NaN         NaN
# 145062         NaN         NaN         NaN         NaN
#
#                                                     Title           Project  \
# 0                                                    2NE1  zh.wikipedia.org
# 1                                                     2PM  zh.wikipedia.org
# 2                                                      3C  zh.wikipedia.org
# 3                                                 4minute  zh.wikipedia.org
# 4                                        52_Hz_I_Love_You  zh.wikipedia.org
# ...                                                   ...               ...
# 145058                    Underworld_(serie_de_películas)  es.wikipedia.org
# 145059                      Resident_Evil:_Capítulo_Final  es.wikipedia.org
# 145060                              Enamorándome_de_Ramón  es.wikipedia.org
# 145061                             Hasta_el_último_hombre  es.wikipedia.org
# 145062  Francisco_el_matemático_(serie_de_televisión_d...  es.wikipedia.org
#
#             Access   Agent
# 0       all-access  spider
# 1       all-access  spider
# 2       all-access  spider
# 3       all-access  spider
# 4       all-access  spider
# ...            ...     ...
# 145058  all-access  spider
# 145059  all-access  spider
# 145060  all-access  spider
# 145061  all-access  spider
# 145062  all-access  spider
#
# [145063 rows x 555 columns]

# %%
# Identify rows where the extraction failed (any NaN in the new columns)
problem_rows = data[data[['Title', 'Project', 'Access', 'Agent']].isnull().any(axis=1)]
print(problem_rows)
# drop page column and reorder columns to have the new columns first
data = data.drop(columns=['Title'])
data['Title'] = data['Page']
data = data.drop(columns=['Page'])
display(data)
# Out:
# Empty DataFrame
# Columns: [Page, 2015-07-01, 2015-07-02, 2015-07-03, 2015-07-04, 2015-07-05, 2015-07-06, 2015-07-07, 2015-07-08, 2015-07-09, 2015-07-10, 2015-07-11, 2015-07-12, 2015-07-13, 2015-07-14, 2015-07-15, 2015-07-16, 2015-07-17, 2015-07-18, 2015-07-19, 2015-07-20, 2015-07-21, 2015-07-22, 2015-07-23, 2015-07-24, 2015-07-25, 2015-07-26, 2015-07-27, 2015-07-28, 2015-07-29, 2015-07-30, 2015-07-31, 2015-08-01, 2015-08-02, 2015-08-03, 2015-08-04, 2015-08-05, 2015-08-06, 2015-08-07, 2015-08-08, 2015-08-09, 2015-08-10, 2015-08-11, 2015-08-12, 2015-08-13, 2015-08-14, 2015-08-15, 2015-08-16, 2015-08-17, 2015-08-18, 2015-08-19, 2015-08-20, 2015-08-21, 2015-08-22, 2015-08-23, 2015-08-24, 2015-08-25, 2015-08-26, 2015-08-27, 2015-08-28, 2015-08-29, 2015-08-30, 2015-08-31, 2015-09-01, 2015-09-02, 2015-09-03, 2015-09-04, 2015-09-05, 2015-09-06, 2015-09-07, 2015-09-08, 2015-09-09, 2015-09-10, 2015-09-11, 2015-09-12, 2015-09-13, 2015-09-14, 2015-09-15, 2015-09-16, 2015-09-17, 2015-09-18, 2015-09-19, 2015-09-20, 2015-09-21, 2015-09-22, 2015-09-23, 2015-09-24, 2015-09-25, 2015-09-26, 2015-09-27, 2015-09-28, 2015-09-29, 2015-09-30, 2015-10-01, 2015-10-02, 2015-10-03, 2015-10-04, 2015-10-05, 2015-10-06, 2015-10-07, ...]
# Index: []
#
# [0 rows x 555 columns]
#         2015-07-01  2015-07-02  2015-07-03  2015-07-04  2015-07-05  \
# 0             18.0        11.0         5.0        13.0        14.0
# 1             11.0        14.0        15.0        18.0        11.0
# 2              1.0         0.0         1.0         1.0         0.0
# 3             35.0        13.0        10.0        94.0         4.0
# 4              NaN         NaN         NaN         NaN         NaN
# ...            ...         ...         ...         ...         ...
# 145058         NaN         NaN         NaN         NaN         NaN
# 145059         NaN         NaN         NaN         NaN         NaN
# 145060         NaN         NaN         NaN         NaN         NaN
# 145061         NaN         NaN         NaN         NaN         NaN
# 145062         NaN         NaN         NaN         NaN         NaN
#
#         2015-07-06  2015-07-07  2015-07-08  2015-07-09  2015-07-10  ...  \
# 0              9.0         9.0        22.0        26.0        24.0  ...
# 1             13.0        22.0        11.0        10.0         4.0  ...
# 2              4.0         0.0         3.0         4.0         4.0  ...
# 3             26.0        14.0         9.0        11.0        16.0  ...
# 4              NaN         NaN         NaN         NaN         NaN  ...
# ...            ...         ...         ...         ...         ...  ...
# 145058         NaN         NaN         NaN         NaN         NaN  ...
# 145059         NaN         NaN         NaN         NaN         NaN  ...
# 145060         NaN         NaN         NaN         NaN         NaN  ...
# 145061         NaN         NaN         NaN         NaN         NaN  ...
# 145062         NaN         NaN         NaN         NaN         NaN  ...
#
#         2016-12-26  2016-12-27  2016-12-28  2016-12-29  2016-12-30  \
# 0             14.0        20.0        22.0        19.0        18.0
# 1              9.0        30.0        52.0        45.0        26.0
# 2              4.0         4.0         6.0         3.0         4.0
# 3             16.0        11.0        17.0        19.0        10.0
# 4              3.0        11.0        27.0        13.0        36.0
# ...            ...         ...         ...         ...         ...
# 145058        13.0        12.0        13.0         3.0         5.0
# 145059         NaN         NaN         NaN         NaN         NaN
# 145060         NaN         NaN         NaN         NaN         NaN
# 145061         NaN         NaN         NaN         NaN         NaN
# 145062         NaN         NaN         NaN         NaN         NaN
#
#         2016-12-31           Project      Access   Agent  \
# 0             20.0  zh.wikipedia.org  all-access  spider
# 1             20.0  zh.wikipedia.org  all-access  spider
# 2             17.0  zh.wikipedia.org  all-access  spider
# 3             11.0  zh.wikipedia.org  all-access  spider
# 4             10.0  zh.wikipedia.org  all-access  spider
# ...            ...               ...         ...     ...
# 145058        10.0  es.wikipedia.org  all-access  spider
# 145059         NaN  es.wikipedia.org  all-access  spider
# 145060         NaN  es.wikipedia.org  all-access  spider
# 145061         NaN  es.wikipedia.org  all-access  spider
# 145062         NaN  es.wikipedia.org  all-access  spider
#
#                                                     Title
# 0                 2NE1_zh.wikipedia.org_all-access_spider
# 1                  2PM_zh.wikipedia.org_all-access_spider
# 2                   3C_zh.wikipedia.org_all-access_spider
# 3              4minute_zh.wikipedia.org_all-access_spider
# 4       52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...
# ...                                                   ...
# 145058  Underworld_(serie_de_películas)_es.wikipedia.o...
# 145059  Resident_Evil:_Capítulo_Final_es.wikipedia.org...
# 145060  Enamorándome_de_Ramón_es.wikipedia.org_all-acc...
# 145061  Hasta_el_último_hombre_es.wikipedia.org_all-ac...
# 145062  Francisco_el_matemático_(serie_de_televisión_d...
#
# [145063 rows x 554 columns]

# %%
# Extract the country code from the Project column
data['CountryCode'] = data['Project'].str.extract(r'^(.*?)\.wikipedia\.org$', expand=False)

# Assign a unique numeric value to each country code (starting at 1)
data['Project_numeric'] = pd.factorize(data['CountryCode'])[0] + 1

data.drop(columns=['CountryCode'], inplace=True)

# %%
display(data[['Project' , 'Project_numeric']])
data = data.drop(columns=['Project'])
# Out:
#                  Project  Project_numeric
# 0       zh.wikipedia.org                1
# 1       zh.wikipedia.org                1
# 2       zh.wikipedia.org                1
# 3       zh.wikipedia.org                1
# 4       zh.wikipedia.org                1
# ...                  ...              ...
# 145058  es.wikipedia.org                7
# 145059  es.wikipedia.org                7
# 145060  es.wikipedia.org                7
# 145061  es.wikipedia.org                7
# 145062  es.wikipedia.org                7
#
# [145063 rows x 2 columns]

# %%
# Factorize the 'Access' column to assign each unique string a numeric value starting at 1
data['Access_numeric'] = pd.factorize(data['Access'])[0] + 1

# Display the first few rows to verify the changes
display(data[['Access', 'Access_numeric']].head())

data = data.drop(columns=['Access'])
# Out:
#        Access  Access_numeric
# 0  all-access               1
# 1  all-access               1
# 2  all-access               1
# 3  all-access               1
# 4  all-access               1

# %%
# same for Agent
data['Agent_numeric'] = pd.factorize(data['Agent'])[0] + 1

# Display the first few rows to verify the changes
display(data[['Agent', 'Agent_numeric']].head())

data = data.drop(columns=['Agent'])
display(data)
# Out:
#     Agent  Agent_numeric
# 0  spider              1
# 1  spider              1
# 2  spider              1
# 3  spider              1
# 4  spider              1
#         2015-07-01  2015-07-02  2015-07-03  2015-07-04  2015-07-05  \
# 0             18.0        11.0         5.0        13.0        14.0
# 1             11.0        14.0        15.0        18.0        11.0
# 2              1.0         0.0         1.0         1.0         0.0
# 3             35.0        13.0        10.0        94.0         4.0
# 4              NaN         NaN         NaN         NaN         NaN
# ...            ...         ...         ...         ...         ...
# 145058         NaN         NaN         NaN         NaN         NaN
# 145059         NaN         NaN         NaN         NaN         NaN
# 145060         NaN         NaN         NaN         NaN         NaN
# 145061         NaN         NaN         NaN         NaN         NaN
# 145062         NaN         NaN         NaN         NaN         NaN
#
#         2015-07-06  2015-07-07  2015-07-08  2015-07-09  2015-07-10  ...  \
# 0              9.0         9.0        22.0        26.0        24.0  ...
# 1             13.0        22.0        11.0        10.0         4.0  ...
# 2              4.0         0.0         3.0         4.0         4.0  ...
# 3             26.0        14.0         9.0        11.0        16.0  ...
# 4              NaN         NaN         NaN         NaN         NaN  ...
# ...            ...         ...         ...         ...         ...  ...
# 145058         NaN         NaN         NaN         NaN         NaN  ...
# 145059         NaN         NaN         NaN         NaN         NaN  ...
# 145060         NaN         NaN         NaN         NaN         NaN  ...
# 145061         NaN         NaN         NaN         NaN         NaN  ...
# 145062         NaN         NaN         NaN         NaN         NaN  ...
#
#         2016-12-26  2016-12-27  2016-12-28  2016-12-29  2016-12-30  \
# 0             14.0        20.0        22.0        19.0        18.0
# 1              9.0        30.0        52.0        45.0        26.0
# 2              4.0         4.0         6.0         3.0         4.0
# 3             16.0        11.0        17.0        19.0        10.0
# 4              3.0        11.0        27.0        13.0        36.0
# ...            ...         ...         ...         ...         ...
# 145058        13.0        12.0        13.0         3.0         5.0
# 145059         NaN         NaN         NaN         NaN         NaN
# 145060         NaN         NaN         NaN         NaN         NaN
# 145061         NaN         NaN         NaN         NaN         NaN
# 145062         NaN         NaN         NaN         NaN         NaN
#
#         2016-12-31                                              Title  \
# 0             20.0            2NE1_zh.wikipedia.org_all-access_spider
# 1             20.0             2PM_zh.wikipedia.org_all-access_spider
# 2             17.0              3C_zh.wikipedia.org_all-access_spider
# 3             11.0         4minute_zh.wikipedia.org_all-access_spider
# 4             10.0  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...
# ...            ...                                                ...
# 145058        10.0  Underworld_(serie_de_películas)_es.wikipedia.o...
# 145059         NaN  Resident_Evil:_Capítulo_Final_es.wikipedia.org...
# 145060         NaN  Enamorándome_de_Ramón_es.wikipedia.org_all-acc...
# 145061         NaN  Hasta_el_último_hombre_es.wikipedia.org_all-ac...
# 145062         NaN  Francisco_el_matemático_(serie_de_televisión_d...
#
#         Project_numeric  Access_numeric  Agent_numeric
# 0                     1               1              1
# 1                     1               1              1
# 2                     1               1              1
# 3                     1               1              1
# 4                     1               1              1
# ...                 ...             ...            ...
# 145058                7               1              1
# 145059                7               1              1
# 145060                7               1              1
# 145061                7               1              1
# 145062                7               1              1
#
# [145063 rows x 554 columns]

# %%
import pandas as pd

# Define the date columns 
date_columns = data.columns[:-4]  # Assuming last 4 columns are Title, Project, Project_numeric, etc.

# Melt the dataframe to transform it into long format i.e. one row per Date-Pageview combo
df_long = data.melt(id_vars=['Title', 'Project_numeric', 'Access_numeric', 'Agent_numeric'],
                  value_vars=date_columns, var_name='Date', value_name='Views')  # Renamed 'Pageviews' to 'Views'

# Convert Date column to datetime format
df_long['Date'] = pd.to_datetime(df_long['Date'])

# Drop any rows where Views are NaN (optional, depending on your needs)
df_long.dropna(subset=['Views'], inplace=True)

# Reset index after melting
df_long.reset_index(drop=True, inplace=True)

# Display the first few rows
print(df_long.head())
# Out:
#                                         Title  Project_numeric  \
# 0     2NE1_zh.wikipedia.org_all-access_spider                1
# 1      2PM_zh.wikipedia.org_all-access_spider                1
# 2       3C_zh.wikipedia.org_all-access_spider                1
# 3  4minute_zh.wikipedia.org_all-access_spider                1
# 4     5566_zh.wikipedia.org_all-access_spider                1
#
#    Access_numeric  Agent_numeric       Date  Views
# 0               1              1 2015-07-01   18.0
# 1               1              1 2015-07-01   11.0
# 2               1              1 2015-07-01    1.0
# 3               1              1 2015-07-01   35.0
# 4               1              1 2015-07-01   12.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from joblib import Parallel, delayed  # For parallel processing
import os

# Ensure 'Views' column is numeric
df_long['Views'] = pd.to_numeric(df_long['Views'], errors='coerce')

# Sort the data by Date
df_long.sort_values(by=['Title', 'Date'], inplace=True)

# Create date features
df_long['dayofweek'] = df_long['Date'].dt.dayofweek
df_long['dayofmonth'] = df_long['Date'].dt.day
df_long['dayofyear'] = df_long['Date'].dt.dayofyear
df_long['month'] = df_long['Date'].dt.month
df_long['year'] = df_long['Date'].dt.year

# Features used for sliding window
features = ['Project_numeric', 'Access_numeric', 'Agent_numeric', 'dayofweek', 'dayofmonth', 'dayofyear', 'month', 'year']
seq_length = 7

# Split the dataset based on the defined date
split_date = '2016-06-01'

train = df_long[df_long['Date'] < split_date]
test = df_long[df_long['Date'] >= split_date]
# Directory for saving CSV files
output_dir = "../data/sliding_window_batches"
os.makedirs(output_dir, exist_ok=True)

# Function to create sliding windows and save to CSV
def sliding_windows_to_csv(data, seq_length, output_dir, prefix="batch"):
    group_num = 0
    grouped = data.groupby('Title')
    
    for _, group in grouped:
        group = group[features + ['Views']].reset_index(drop=True)  # Reset index for each group
        x = []
        y = []
        
        for i in range(len(group) - seq_length):
            _x = group.iloc[i:i+seq_length][features].values
            _y = group.iloc[i+seq_length]['Views']
            x.append(_x)
            y.append(_y)
        
        # Convert x and y to DataFrame
        x_df = pd.DataFrame(np.array(x).reshape(-1, len(features) * seq_length), columns=[f"{f}_{i}" for f in features for i in range(seq_length)])
        y_df = pd.DataFrame(y, columns=['Views'])
        
        # Combine x and y into a single DataFrame
        result_df = pd.concat([x_df, y_df], axis=1)
        
        # Save this group to a CSV file
        batch_filename = f"{output_dir}/{prefix}_group_{group_num}.csv"
        result_df.to_csv(batch_filename, index=False)
        
        # Increment group number for naming
        group_num += 1

# Apply the function to both train and test datasets
sliding_windows_to_csv(train, seq_length, output_dir, prefix="train")
sliding_windows_to_csv(test, seq_length, output_dir, prefix="test")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 63
#      60         group_num += 1
#      62 # Apply the function to both train and test datasets
# ---> 63 sliding_windows_to_csv(train, seq_length, output_dir, prefix="train")
#      64 sliding_windows_to_csv(test, seq_length, output_dir, prefix="test")
#
# Cell In[13], line 43, in sliding_windows_to_csv(data, seq_length, output_dir, prefix)
#      40 y = []
#      42 for i in range(len(group) - seq_length):
# ---> 43     _x = group.iloc[i:i+seq_length][features].values
#      44     _y = group.iloc[i+seq_length]['Views']
#      45     x.append(_x)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3819, in DataFrame.__getitem__(self, key)
#    3816 if getattr(indexer, "dtype", None) == bool:
#    3817     indexer = np.where(indexer)[0]
# -> 3819 data = self._take_with_is_copy(indexer, axis=1)
#    3821 if is_single_key:
#    3822     # What does looking for a single key in a non-unique index return?
#    3823     # The behavior is inconsistent. It returns a Series, except when
#    3824     # - the key itself is repeated (test on data.shape, #9519), or
#    3825     # - we have a MultiIndex on columns (test on self.columns, #21309)
#    3826     if data.shape[1] == 1 and not isinstance(self.columns, MultiIndex):
#    3827         # GH#26490 using data[key] can cause RecursionError
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:3902, in NDFrame._take_with_is_copy(self, indices, axis)
#    3894 def _take_with_is_copy(self: NDFrameT, indices, axis=0) -> NDFrameT:
#    3895     """
#    3896     Internal version of the `take` method that sets the `_is_copy`
#    3897     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3900     See the docstring of `take` for full explanation of the parameters.
#    3901     """
# -> 3902     result = self._take(indices=indices, axis=axis)
#    3903     # Maybe set copy if we didn't actually change the index.
#    3904     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:3884, in NDFrame._take(self, indices, axis, convert_indices)
#    3873 def _take(
#    3874     self: NDFrameT,
#    3875     indices,
#    3876     axis=0,
#    3877     convert_indices: bool_t = True,
#    3878 ) -> NDFrameT:
#    3879     """
#    3880     Internal version of the `take` allowing specification of additional args.
#    3881
#    3882     See the docstring of `take` for full explanation of the parameters.
#    3883     """
# -> 3884     self._consolidate_inplace()
#    3886     new_data = self._mgr.take(
#    3887         indices,
#    3888         axis=self._get_block_manager_axis(axis),
#    3889         verify=True,
#    3890         convert_indices=convert_indices,
#    3891     )
#    3892     return self._constructor(new_data).__finalize__(self, method="take")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5980, in NDFrame._consolidate_inplace(self)
#    5977 def f():
#    5978     self._mgr = self._mgr.consolidate()
# -> 5980 self._protect_consolidate(f)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5968, in NDFrame._protect_consolidate(self, f)
#    5966     return f()
#    5967 blocks_before = len(self._mgr.blocks)
# -> 5968 result = f()
#    5969 if len(self._mgr.blocks) != blocks_before:
#    5970     self._clear_item_cache()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5978, in NDFrame._consolidate_inplace.<locals>.f()
#    5977 def f():
# -> 5978     self._mgr = self._mgr.consolidate()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# KeyboardInterrupt:

# %%
# del df_long
# del data

# # normalize X with min max scaler apparently normalizing y is problematic for 
# # Xgboost and other tree based models
# scaler = MinMaxScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)


# print("Training data shape:", X_train.shape, y_train.shape)
# print("Testing data shape:", X_test.shape, y_test.shape)
# Out:
# Training data shape: (42824617, 15) (42824617,)
# Testing data shape: (29757001, 15) (29757001,)
